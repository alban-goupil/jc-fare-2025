# %% [markdown]
# # Impact du nombre d'observations

# %%
# !pip install numpy
# !pip install matplotlib

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

plt.rcParams['figure.figsize'] = [8.6, 6]
#plt.rcParams['figure.dpi'] = 100

# %%
X = np.genfromtxt('data/points.csv', delimiter=',')
n, m = X.shape
assert m == 2

# %%
nobs = 10 # Nombres d'observation

fig, axs = plt.subplots(ncols=2)
for ax in axs:
    ax.set_aspect('equal')
    ax.set_xlim(-0.2, 1.2)
    ax.set_ylim(-0.2, 1.2)
    ax.scatter(X[:nobs,0], X[:nobs,1])
# Modèle 1 : le rectangle
xmin, ymin = np.min(X[:nobs, :], axis=0)
xmax, ymax = np.max(X[:nobs,:], axis=0)
axs[0].add_artist(mpatches.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='g', alpha=0.2))
# Modèle 2 : le disque
ctr = np.mean(X[:nobs, :], axis=0)
rayon = np.max(np.linalg.norm(X[:nobs, :] - ctr, axis=1))
axs[1].add_artist(mpatches.Circle(ctr, rayon, color='g', alpha=0.2))
